# %%
import streamlit as st
from tensorflow.keras.models import load_model
from PIL import Image
import numpy as np

# Load the saved model
MODEL_PATH = 'bean_disease_model.keras'
model = load_model(MODEL_PATH)

# Define the class names (replace with your actual class names)
class_names = ['Healthy', 'Angular Leaf Spot', 'Bean Rust']

# Function to preprocess the uploaded image
def preprocess_image(image):
    img = image.resize((128, 128))  # Resize to model's expected input size
    img_array = np.array(img) / 255.0  # Normalize pixel values
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    return img_array

# Streamlit App
st.title("Bean Disease Classification")
st.write("Upload an image of a bean leaf to identify its health condition.")

# File uploader
uploaded_file = st.file_uploader("Choose a bean leaf image", type=["jpg", "jpeg", "png"])

if uploaded_file:
    try:
        # Display the uploaded image
        image = Image.open(uploaded_file)
        st.image(image, caption="Uploaded Image", use_column_width=True)

        # Preprocess the image
        processed_image = preprocess_image(image)

        # Make a prediction
        predictions = model.predict(processed_image)
        predicted_class = class_names[np.argmax(predictions)]
        confidence = np.max(predictions) * 100

        # Display the result
        st.write(f"**Predicted Class:** {predicted_class}")
        st.write(f"**Confidence:** {confidence:.2f}%")
    except Exception as e:
        st.error(f"An error occurred: {e}")

# Error handling for unsupported file types
else:
    st.write("Please upload a valid image file.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import streamlit as st
#       2 from tensorflow.keras.models import load_model
#       3 from PIL import Image
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
# !pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting streamlit
#   Downloading streamlit-1.40.1-py2.py3-none-any.whl (8.6 MB)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: packaging<25,>=20 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from streamlit) (2.2.3)
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting pyarrow>=7.0
#   Downloading pyarrow-18.0.0-cp39-cp39-win_amd64.whl (25.1 MB)
# Collecting cachetools<6,>=4.0
#   Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Collecting watchdog<7,>=2.1.5
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: click<9,>=7.0 in c:\program files\python39\lib\site-packages (from streamlit) (8.1.7)
# Collecting tenacity<10,>=8.1.0
#   Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\program files\python39\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from streamlit) (6.4.1)
# Collecting altair<6,>=4.0
#   Downloading altair-5.5.0-py3-none-any.whl (731 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from streamlit) (13.9.4)
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from streamlit) (3.20.3)
# Collecting narwhals>=1.14.2
#   Downloading narwhals-1.14.2-py3-none-any.whl (225 kB)
# Requirement already satisfied: jinja2 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: colorama in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.21.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from requests<3,>=2.27->streamlit) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vignesh\appdata\roaming\python\python39\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Installing collected packages: smmap, narwhals, gitdb, watchdog, tenacity, pydeck, pyarrow, gitpython, cachetools, blinker, altair, streamlit
# Successfully installed altair-5.5.0 blinker-1.9.0 cachetools-5.5.0 gitdb-4.0.11 gitpython-3.1.43 narwhals-1.14.2 pyarrow-18.0.0 pydeck-0.9.1 smmap-5.0.1 streamlit-1.40.1 tenacity-9.0.0 watchdog-6.0.0
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vignesh\appdata\roaming\python\python39\site-packages)
# WARNING: You are using pip version 21.1.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.
